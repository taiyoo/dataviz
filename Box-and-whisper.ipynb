# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, plot, init_notebook_mode

import pandas as pd
from datetime import datetime

df = pd.read_csv("ExcelFormattedGISTEMPDataCSV.csv")

# %%
init_notebook_mode(True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df['min'] = df.iloc[:,1:13].min(axis=1)
df['max'] = df.iloc[:,1:13].max(axis=1)

# %%
trace = go.Candlestick(x=df.Year,
                       open=df.Jan,
                       high=df['max'],
                       low=df['min'],
                       close=df.Dec)
data = [trace]

layout = {
    'title': 'Global Surface Temperature',
    'xaxis': {'title': 'Year'},
    'yaxis': {'title': 'Degree'}
}

fig = dict(data=data,layout=layout)

iplot(fig, filename='simple_candlestick')
# Out:
# <div id="68b10b93-cfb7-41d6-9daa-2eb08f679794" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("68b10b93-cfb7-41d6-9daa-2eb08f679794", [{"close": ["-20", "-14", "-24", "-17", "-28", "-5", "-24", "-37", "-11", "-29", "-29", "1", "-27", "-36", "-21", "-11", "-11", "-26", "-21", "-26", "-13", "-28", "-45", "-46", "-28", "-20", "-16", "-49", "-49", "-53", "-68", "-24", "-40", "-3", "-9", "-24", "-77", "-70", "-27", "-33", "-44", "-17", "-15", "-3", "-40", "11", "-29", "-35", "-19", "-53", "-7", "-9", "-22", "-45", "-7", "-20", "-1", "-9", "-23", "41", "20", "15", "14", "29", "8", "-8", "-27", "-15", "-20", "-15", "-19", "16", "-2", "4", "-16", "-32", "-10", "16", "0", "-2", "18", "-15", "-1", "0", "-30", "-6", "-6", "-2", "-14", "27", "-14", "-8", "18", "-6", "-10", "-17", "8", "5", "11", "48", "20", "4
# ...
